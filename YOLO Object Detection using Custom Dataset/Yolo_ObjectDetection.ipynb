# %%
# !mkdir Project

# %%
# !unzip /content/drive/MyDrive/Annotation.zip -d /content/Project
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/Project/__MACOSX/Annotation/._n02105251_7090.xml
#   inflating: /content/Project/Annotation/n02105855_7607.xml
#   inflating: /content/Project/__MACOSX/Annotation/._n02105855_7607.xml
#   inflating: /content/Project/Annotation/n02088632_2736.xml
#   inflating: /content/Project/__MACOSX/Annotation/._n02088632_2736.xml
#   inflating: /content/Project/Annotation/n02113978_2141.xml
#   inflating: /content/Project/__MACOSX/Annotation/._n02113978_2141.xml
#   inflating: /content/Project/Annotation/n02112018_10129.xml
#   inflating: /content/Project/__MACOSX/Annotation/._n02112018_10129.xml
#   inflating: /content/Project/Annotation/n02098105_2897.xml
#   inflating: /content/Project/__MACOSX/Annotation/._n02098105_2897.xml
#   inflating: /content/Project/Annotation/n02097658_983.xml
#   inflating: /content/Project/__MACOSX/Annotation/._n02097658_983.xml
#   inflating: /content/Project/Annotation/n02105855_12455.xml
# ...

# %%
# !ls /content/Project/Annotation | wc -l
# Out:
# 20580

# %%
# !unzip /content/drive/MyDrive/Images.zip -d /content/Project
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/Project/__MACOSX/Images/._n02093991_5001.jpg
#   inflating: /content/Project/Images/n02085936_719.jpg
#   inflating: /content/Project/__MACOSX/Images/._n02085936_719.jpg
#   inflating: /content/Project/Images/n02102318_3269.jpg
#   inflating: /content/Project/__MACOSX/Images/._n02102318_3269.jpg
#   inflating: /content/Project/Images/n02112137_2825.jpg
#   inflating: /content/Project/__MACOSX/Images/._n02112137_2825.jpg
#   inflating: /content/Project/Images/n02102040_3006.jpg
#   inflating: /content/Project/__MACOSX/Images/._n02102040_3006.jpg
#   inflating: /content/Project/Images/n02097130_4467.jpg
#   inflating: /content/Project/__MACOSX/Images/._n02097130_4467.jpg
#   inflating: /content/Project/Images/n02100877_295.jpg
#   inflating: /content/Project/__MACOSX/Images/._n02100877_295.jpg
#   inflating: /content/Project/Images/n02102177_3371.jpg
# ...

# %%
# !ls /content/Project/Images | wc -l
# Out:
# 20580

# %%
# %cd /content/Project
# Out:
# /content/Project

# %%
#to convert xml files of label to txt yolo format
# !python convert.py
# Out:
# Streaming output truncated to the last 5000 lines.
# wrote /content/Project/Annotation/n02106662_14247.txt
# wrote /content/Project/Annotation/n02091635_965.txt
# wrote /content/Project/Annotation/n02115641_5798.txt
# wrote /content/Project/Annotation/n02097047_731.txt
# wrote /content/Project/Annotation/n02106166_243.txt
# wrote /content/Project/Annotation/n02085936_6892.txt
# wrote /content/Project/Annotation/n02094433_2125.txt
# wrote /content/Project/Annotation/n02104365_3383.txt
# wrote /content/Project/Annotation/n02108089_12739.txt
# wrote /content/Project/Annotation/n02091244_1714.txt
# wrote /content/Project/Annotation/n02096294_7732.txt
# wrote /content/Project/Annotation/n02115641_9067.txt
# wrote /content/Project/Annotation/n02110627_11942.txt
# wrote /content/Project/Annotation/n02106382_4602.txt
# wrote /content/Project/Annotation/n02108551_957.txt
# wrote /content/Project/Annotation/n02113023_6383.txt
# wrote /content/Project/Annotation/n02113023_10636.txt
# ...

# %%
#keep txt files in same folder as jpg files
# !mv /content/Project/Annotation/*.txt /content/Project/Images/

# %%
# !ls /content/Project/Images | wc -l
# Out:
# 41160

# %%
# !rm -rf /content/Project/darknet

# %%
# %cd /content/
# Out:
# /content

# %%
#clone yolo repo
# !git clone https://github.com/pjreddie/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 5931, done.
# remote: Total 5931 (delta 0), reused 0 (delta 0), pack-reused 5931
# Receiving objects: 100% (5931/5931), 6.34 MiB | 24.70 MiB/s, done.
# Resolving deltas: 100% (3925/3925), done.

# %%
# !rm -rf /content/darknet/data/*.txt

# %%
#copying dataset from project directory to data labels folder
# !cp -r /content/Project/Images /content/darknet/data/labels

# %%
#split data to train and test
# !python /content/darknet/process.py

# %%
#move train.txt and test.txt to data folder
# !mv /content/train.txt /content/darknet/data/

# %%
# !mv /content/test.txt /content/darknet/data/

# %%
#create yolo.names and yolo.data in darknet/data folder

# %%
# %cd /content/darknet 
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# /content/darknet
# --2021-03-04 06:59:47--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  20.5MB/s    in 8.4s
#
# 2021-03-04 06:59:56 (18.4 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
#zip all the changes done in darknet repo and move it to drive
# !zip -r /content/darknet.zip /content/darknet/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: content/darknet/data/images/n02095314_969.txt (deflated 21%)
#   adding: content/darknet/data/images/n02093256_2737.jpg (deflated 1%)
#   adding: content/darknet/data/images/n02099429_853.txt (deflated 8%)
#   adding: content/darknet/data/images/n02092339_792.jpg (deflated 0%)
#   adding: content/darknet/data/images/n02105641_126.txt (deflated 26%)
#   adding: content/darknet/data/images/n02099601_5132.txt (deflated 13%)
#   adding: content/darknet/data/images/n02108551_2921.txt (deflated 31%)
#   adding: content/darknet/data/images/n02090379_2733.jpg (deflated 0%)
#   adding: content/darknet/data/images/n02106550_4920.txt (deflated 18%)
#   adding: content/darknet/data/images/n02107908_5162.txt (deflated 23%)
#   adding: content/darknet/data/images/n02088632_28.txt (deflated 8%)
#   adding: content/darknet/data/images/n02107312_7391.jpg (deflated 0%)
# ...

# %%
# !mv /content/darknet.zip /content/drive/MyDrive/
